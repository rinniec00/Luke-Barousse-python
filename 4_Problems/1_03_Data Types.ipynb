# %% [markdown]
# <a href="https://colab.research.google.com/github/rinniec00/Luke-Barousse-python/blob/main/4_Problems/1_03_Data%20Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_03_Data Types.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Check Data Type (1.3.1)

# %%
# Code Needed
job_title = 'Data Scientist'
print(type(job_title))
# Out:
# <class 'str'>

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Check Float Type (1.3.2)

# %%
# Code Needed
salary = 85000.50
print(type(salary))
# Out:
# <class 'float'>

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Convert to Integer (1.3.3)

# %%
# Code Needed
salary_rate = 120000.75
salary_rate = int(salary_rate)
print(type(salary_rate))
# Out:
# <class 'int'>

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Check String Type (1.3.4)

# %%
# Code Needed
company_name = 'DataWiz Inc.'
(isinstance(company_name,str))
# Out:
# True

# %% [markdown]
# ---
